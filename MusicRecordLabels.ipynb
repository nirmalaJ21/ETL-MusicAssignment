# %% [markdown]
# #  Music Record Labels
#     ETL, XML, Consuming API, SQL

# %% [markdown]
# # Task: Use Discogs’ publicly available data to build an ETL pipeline (in python) that creates a table of music label information.

# %% [markdown]
# # What will the application do?

# %% [markdown]
# ## Extract data from the monthly XML dump file of all labels into a pandas DataFrame

# %%
import pandas as pd
import time
import psycopg2
def extract():
# Read the XML file and convert it into a DataFrame
 df = pd.read_xml('C:\\Users\\paperspace\\Downloads\\MusicLabel\\discogs_20230101_labels.xml', xpath='//labels/label')
 return df
# Print the DataFrame
df = extract()
df
# Out:
#          images       id                             name  \
# 0           NaN        1                         Planet E
# 1           NaN        2            Earthtones Recordings
# 2           NaN        3               Seasons Recordings
# 3           NaN        4                     Siesta Music
# 4           NaN        5                             Svek
# ...         ...      ...                              ...
# 1946241     NaN  3078049             5th Gear Productions
# 1946242     NaN  3078052              Tunnell, Jimi Music
# 1946243     NaN  3078055           Warrior Gospel Records
# 1946244     NaN  3078058                 Allegretto Music
# 1946245     NaN  3078061  A Compilation Of Portland Music
#
#                                                contactinfo  \
# 0        Planet E Communications\r\nP.O. Box 27218\r\nD...
# 1        Seasons Recordings\r\n2236 Pacific Avenue\r\nS...
# 2        Seasons Recordings\r\nCosta Mesa, CA 92627\r\n...
# 3        Siesta Records\r\n1913 Via Encantadoras\r\nSan...
# 4        Svek office \r\nStephan Grieder \r\nFax: +46 (...
# ...                                                    ...
# 1946241                                               None
# 1946242                                               None
# 1946243                                               None
# 1946244                                               None
# 1946245                                               None
#
#                                                    profile  \
# 0        [a=Carl Craig]'s classic techno label founded ...
# 1        California deep house label founded by [a=Jami...
# 2        California deep-house label founded by [a=Jami...
# 3                                                     None
# 4                                                     None
# ...                                                    ...
# 1946241                                               None
# 1946242                                               None
# 1946243                                               None
# 1946244                                               None
# 1946245  Compilation series by Failing Records of artis...
#
#                 data_quality  urls  sublabels      parentLabel
# 0                 Needs Vote   NaN        NaN             None
# 1                    Correct   NaN        NaN             None
# 2                 Needs Vote   NaN        NaN             None
# 3                 Needs Vote   NaN        NaN             None
# 4                    Correct   NaN        NaN   Goldhead Music
# ...                      ...   ...        ...              ...
# 1946241  Needs Major Changes   NaN        NaN             None
# 1946242  Needs Major Changes   NaN        NaN             None
# 1946243  Needs Major Changes   NaN        NaN             None
# 1946244  Needs Major Changes   NaN        NaN             None
# 1946245           Needs Vote   NaN        NaN  Failing Records
#
# [1946246 rows x 9 columns]

# %% [markdown]
# *INSPECTING DATA SET*

# %%
df.head()
# Out:
#    images  id                   name  \
# 0     NaN   1               Planet E
# 1     NaN   2  Earthtones Recordings
# 2     NaN   3     Seasons Recordings
# 3     NaN   4           Siesta Music
# 4     NaN   5                   Svek
#
#                                          contactinfo  \
# 0  Planet E Communications\r\nP.O. Box 27218\r\nD...
# 1  Seasons Recordings\r\n2236 Pacific Avenue\r\nS...
# 2  Seasons Recordings\r\nCosta Mesa, CA 92627\r\n...
# 3  Siesta Records\r\n1913 Via Encantadoras\r\nSan...
# 4  Svek office \r\nStephan Grieder \r\nFax: +46 (...
#
#                                              profile data_quality  urls  \
# 0  [a=Carl Craig]'s classic techno label founded ...   Needs Vote   NaN
# 1  California deep house label founded by [a=Jami...      Correct   NaN
# 2  California deep-house label founded by [a=Jami...   Needs Vote   NaN
# 3                                               None   Needs Vote   NaN
# 4                                               None      Correct   NaN
#
#    sublabels     parentLabel
# 0        NaN            None
# 1        NaN            None
# 2        NaN            None
# 3        NaN            None
# 4        NaN  Goldhead Music

# %%
df.tail()
# Out:
#          images       id                             name contactinfo  \
# 1946241     NaN  3078049             5th Gear Productions        None
# 1946242     NaN  3078052              Tunnell, Jimi Music        None
# 1946243     NaN  3078055           Warrior Gospel Records        None
# 1946244     NaN  3078058                 Allegretto Music        None
# 1946245     NaN  3078061  A Compilation Of Portland Music        None
#
#                                                    profile  \
# 1946241                                               None
# 1946242                                               None
# 1946243                                               None
# 1946244                                               None
# 1946245  Compilation series by Failing Records of artis...
#
#                 data_quality  urls  sublabels      parentLabel
# 1946241  Needs Major Changes   NaN        NaN             None
# 1946242  Needs Major Changes   NaN        NaN             None
# 1946243  Needs Major Changes   NaN        NaN             None
# 1946244  Needs Major Changes   NaN        NaN             None
# 1946245           Needs Vote   NaN        NaN  Failing Records

# %%
df['data_quality'].value_counts()
# Out:
# Needs Major Changes     1333815
# Needs Vote               474834
# Correct                  132960
# Complete and Correct       4633
# Needs Minor Changes           3
# Entirely Incorrect            1
# Name: data_quality, dtype: int64

# %% [markdown]
# # Transform data
#
# In accordance with the Build Specifications below
# Additionally by using the Discogs API to add the following additional columns:
#
# Total number of releases: How many total releases does the label have?
#
# Minimum release year: What year was the label’s first release?
#
# Maximum release year: What year was the label’s last release?
#
#     Remove any labels where: (1 Point)
#     Data quality is not listed as “Complete and Correct”
#     Contact information is missing

# %%
def transform(df):

     df = df[~df['data_quality'].isin(['Needs Major Changes', 'Needs Vote', 'Correct', 'Needs Minor Changes', 'Entirely Incorrect'])]
     df = df[df['contactinfo'].notna()]
     return df

# %%
df1 = transform(df)
df1
# Out:
#          images       id                                name  \
# 725         NaN      774                   Hed Kandi Records
# 2878        NaN     3141                             Concept
# 2935        NaN     3203                  Tinnitus Tonträger
# 3020        NaN     3295                  Taaach! Recordings
# 3505        NaN     3824                                Fuse
# ...         ...      ...                                 ...
# 1837333     NaN  2731304                ELUSIVE INTELLIGENCE
# 1838109     NaN  2733764                  Axe & Trap Studios
# 1854531     NaN  2786228                              Εν Πλω
# 1882605     NaN  2875724  Doppelkirche Bonn-Schwarzrheindorf
# 1918553     NaN  2990383                          Imp. Nasra
#
#                                                contactinfo  \
# 725      MSHK Limited\r\n103 Gaunt Street\r\nLondon, SE...
# 2878     Concept Records\r\n24A Barry Street\r\nBradfor...
# 2935     Tinnitus Tonträger\r\nMarc Göttling\r\nWiesent...
# 3020     Taaach!\r\nEdition Chrome\r\nPostfach 10 50 54...
# 3505     Fuse\r\nbkb Dance Department gmbh\r\nAuhofstra...
# ...                                                    ...
# 1837333           childhoodintelligenceworldwide@gmail.com
# 1838109  Underwood Business Park\r\nWookey Hole Road\r\...
# 1854531  Κολοκοτρώνη 49, 105 60 Αθήνα\r\n+302103226343 ...
# 1882605  Doppelkirche St. Maria und St. Clemens\r\nDixs...
# 1918553               Imp. Nasra\r\n3, Rue Vesoul\r\nTunis
#
#                                                    profile  \
# 725      Record company of the UK-based house label [l6...
# 2878     Trance label from the UK. The label becomes [l...
# 2935             Style: hard kicking minimal techno traxx.
# 3020     German Trance Label\r\nDistributed by InterGro...
# 3505     German Trance label\r\nDistributed by Music Ma...
# ...                                                    ...
# 1837333                                               None
# 1838109  Recording studio located in the city of Wells,...
# 1854531          Publishing company for books, music etc..
# 1882605  Catholic parish church in Romanesque style fro...
# 1918553                Printing company located in Tunisia
#
#                  data_quality  urls  sublabels             parentLabel
# 725      Complete and Correct   NaN        NaN       Ministry Of Sound
# 2878     Complete and Correct   NaN        NaN     Global Beat Records
# 2935     Complete and Correct   NaN        NaN                    None
# 3020     Complete and Correct   NaN        NaN                    None
# 3505     Complete and Correct   NaN        NaN         Massive Records
# ...                       ...   ...        ...                     ...
# 1837333  Complete and Correct   NaN        NaN  Childhood Intelligence
# 1838109  Complete and Correct   NaN        NaN                    None
# 1854531  Complete and Correct   NaN        NaN                    None
# 1882605  Complete and Correct   NaN        NaN                    None
# 1918553  Complete and Correct   NaN        NaN                    None
#
# [427 rows x 9 columns]

# %%
df.describe()
# Out:
#        images            id  urls  sublabels
# count     0.0  1.946246e+06   0.0        0.0
# mean      NaN  1.260010e+06   NaN        NaN
# std       NaN  7.955305e+05   NaN        NaN
# min       NaN  1.000000e+00   NaN        NaN
# 25%       NaN  5.996582e+05   NaN        NaN
# 50%       NaN  1.185466e+06   NaN        NaN
# 75%       NaN  1.796164e+06   NaN        NaN
# max       NaN  3.078061e+06   NaN        NaN

# %%
df.dtypes
# Out:
# images          float64
# id                int64
# name             object
# contactinfo      object
# profile          object
# data_quality     object
# urls            float64
# sublabels       float64
# parentLabel      object
# dtype: object

# %%
df.columns
# Out:
# Index(['images', 'id', 'name', 'contactinfo', 'profile', 'data_quality',
#        'urls', 'sublabels', 'parentLabel'],
#       dtype='object')

# %%
import requests
import time

def get_label_info(label_id):
    base_url = 'https://api.discogs.com/labels/'
    label_url = base_url + str(label_id) + '/releases'

    try:
        response = requests.get(label_url)
        if response.status_code == 200:
            label_info = response.json()
            return label_info
        else:
            print(f"{time.strftime('%H:%M:%S')} | Failed API call for label {label_id}")
            return None
    except requests.exceptions.RequestException as e:
        print(f"{time.strftime('%H:%M:%S')} | Failed API call for label {label_id}: {e}")
        return None

# Example usage
label_id = '25'  # Replace with the actual label ID
df_label_info = get_label_info(label_id)
print(df_label_info)

# # Select specific keys from label_info dictionary
# keys_to_include = ['releases']  # Replace with the keys you want to include
# filtered_label_info = {key: label_info[key] for key in keys_to_include}

# # Convert filtered_label_info to DataFrame
# df_label_info = pd.DataFrame(filtered_label_info)

# # Print the DataFrame
# print(df_label_info)
# Out:
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 37, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': 'UNDJACD014', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/56598', 'title': 'United DJs Of America - Volume 14', 'id': 56598, 'year': 2000, 'artist': 'Soul Slinger*'}, {'status': 'Accepted', 'format': 'CD, Mixed, RE', 'catno': '7930185511-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/2010288', 'title': 'Blazing The Crop - Rewind', 'id': 2010288, 'year': 2002, 'artist': 'Rae And Christian*'}, {'status': 'Accepted', 'format': 'CD, Mixed, RE', 'catno': '7930185507-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/559306', 'title': "Monsieur Dimitri's De-Luxe House Of Funk - Rewind", 'id': 559306, 'year': 2001, 'artist': 'Dimitri From Paris'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed, RE', 'catno': '7930185505-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/340431', 'title': 'Rewind', 'id': 340431, 'year': 2001, 'artist': 'Mark Farina'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': '7930185501-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/2511', 'title': 'United DJs Of America - Volume 15', 'id': 2511, 'year': 2000, 'artist': 'David Alvarado'}, {'status': 'Accepted', 'format': 'CD, Mixed', 'catno': '7930185516-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/797916', 'title': 'United DJs Of America Vol. 20', 'id': 797916, 'year': 2003, 'artist': 'Marques Wyatt'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': '7930185510-2, UNDJ A CD 18', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/48497', 'title': 'United DJs Of America - Volume 18', 'id': 48497, 'year': 2002, 'artist': 'Tony Humphries'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': '7930185502-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/60588', 'title': 'United DJs Of America - Volume 16', 'id': 60588, 'year': 2000, 'artist': 'DJ Craze'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed, RE', 'catno': '7930185506-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/579264', 'title': 'One Sound System One Music - Rewind', 'id': 579264, 'year': 2001, 'artist': 'Soul Slinger* Featuring Supa MC TC Izlam*'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': '7930185510-2, UNDJ A CD 18', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/48497', 'title': 'United DJs Of America - Volume 18', 'id': 48497, 'year': 2002, 'artist': 'Tony Humphries'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': '7930185518-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/521631', 'title': 'Back To Mine', 'id': 521631, 'year': 2002, 'artist': 'Orbital'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': '7930185521-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/432833', 'title': 'Next School Volume 2', 'id': 432833, 'year': 2002, 'artist': 'Plus One*'}, {'status': 'Accepted', 'format': 'CD, Mixed', 'catno': '7930185513-2 8', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/109318', 'title': "Drum'n'Bass Mix", 'id': 109318, 'year': 2001, 'artist': 'J.Majik*'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': '7930185512-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/2829291', 'title': 'United DJs Of America - Volume 19', 'id': 2829291, 'year': 2001, 'artist': 'John Kelley'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed, RE', 'catno': '7930185503-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/637918', 'title': 'The Takeover Bid - Rewind', 'id': 637918, 'year': 2001, 'artist': 'Aphrodite'}, {'status': 'Accepted', 'format': 'CD, Comp, Mixed, RE', 'catno': '7930185508-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/558113', 'title': 'Resonance - Rewind', 'id': 558 ...

# %%
# Normalize the 'releases' column to extract nested keys as columns

df_label_info_normalized = pd.json_normalize(df_label_info['releases'])

# Print the normalized DataFrame
df_label_info_normalized
# Out:
#       status                  format                       catno thumb  \
# 0   Accepted         CD, Comp, Mixed                  UNDJACD014
# 1   Accepted           CD, Mixed, RE                7930185511-2
# 2   Accepted           CD, Mixed, RE                7930185507-2
# 3   Accepted     CD, Comp, Mixed, RE                7930185505-2
# 4   Accepted         CD, Comp, Mixed                7930185501-2
# 5   Accepted               CD, Mixed                7930185516-2
# 6   Accepted         CD, Comp, Mixed  7930185510-2, UNDJ A CD 18
# 7   Accepted         CD, Comp, Mixed                7930185502-2
# 8   Accepted     CD, Comp, Mixed, RE                7930185506-2
# 9   Accepted         CD, Comp, Mixed  7930185510-2, UNDJ A CD 18
# 10  Accepted         CD, Comp, Mixed                7930185518-2
# 11  Accepted         CD, Comp, Mixed                7930185521-2
# 12  Accepted               CD, Mixed              7930185513-2 8
# 13  Accepted         CD, Comp, Mixed                7930185512-2
# 14  Accepted     CD, Comp, Mixed, RE                7930185503-2
# 15  Accepted     CD, Comp, Mixed, RE                7930185508-2
# 16  Accepted         CD, Comp, Mixed                7930185509-2
# 17  Accepted         CD, Comp, Mixed                7930185523-2
# 18  Accepted       2xCD, Comp, Mixed                7930185514-2
# 19  Accepted           CD, Mixed, RE                7930185504-2
# 20  Accepted               CD, Mixed                7930185517-2
# 21  Accepted               CD, Mixed                7930185522-2
# 22  Accepted  CD, Comp, Mixed, Promo                  DM 40012-2
# 23  Accepted         CD, Comp, Mixed                  DM 40012-2
# 24  Accepted               CD, Mixed                   DM40009-2
# 25  Accepted               CD, Mixed                   DM40010-2
# 26  Accepted               CD, Mixed                   DM40011-2
# 27  Accepted        CD, Mixed, Promo                   DM40011-2
# 28  Accepted         CD, Comp, Mixed                   DM40013-2
# 29  Accepted  CD, Comp, Mixed, Promo                   DM40013-2
# 30  Accepted         CD, Comp, Mixed                 MIX 60008-2
# 31  Accepted               CD, Mixed                 MIX 60009-2
# 32  Accepted  CD, Comp, Mixed, Promo                  MIX60008-2
# 33  Accepted  CD, Comp, Mixed, Promo                  MIX60009-2
# 34  Accepted               CD, Mixed                  MIX60010-2
# 35  Accepted               CD, Mixed                  MIX60011-2
# 36  Accepted         CD, Comp, Mixed                  MIX60013-2
#
#                                  resource_url  \
# 0      https://api.discogs.com/releases/56598
# 1    https://api.discogs.com/releases/2010288
# 2     https://api.discogs.com/releases/559306
# 3     https://api.discogs.com/releases/340431
# 4       https://api.discogs.com/releases/2511
# 5     https://api.discogs.com/releases/797916
# 6      https://api.discogs.com/releases/48497
# 7      https://api.discogs.com/releases/60588
# 8     https://api.discogs.com/releases/579264
# 9      https://api.discogs.com/releases/48497
# 10    https://api.discogs.com/releases/521631
# 11    https://api.discogs.com/releases/432833
# 12    https://api.discogs.com/releases/109318
# 13   https://api.discogs.com/releases/2829291
# 14    https://api.discogs.com/releases/637918
# 15    https://api.discogs.com/releases/558113
# 16    https://api.discogs.com/releases/221053
# 17    https://api.discogs.com/releases/565185
# 18   https://api.discogs.com/releases/4202627
# 19    https://api.discogs.com/releases/569231
# 20   https://api.discogs.com/releases/4645352
# 21   https://api.discogs.com/releases/1128246
# 22  https://api.discogs.com/releases/11296550
# 23     https://api.discogs.com/releases/70913
# 24     https://api.discogs.com/releases/67015
# 25    https://api.discogs.com/releases/141176
# 26   https://api.discogs.com/releases/2306628
# 27   https://api.discogs.com/releases/1430785
# 28   https://api.discogs.com/releases/1445008
# 29   https://api.discogs.com/releases/4358707
# 30    https://api.discogs.com/releases/249123
# 31    https://api.discogs.com/releases/646382
# 32   https://api.discogs.com/releases/6083940
# 33   https://api.discogs.com/releases/6083948
# 34        https://api.discogs.com/releases/49
# 35   https://api.discogs.com/releases/4110434
# 36    https://api.discogs.com/releases/210153
#
#                                                 title        id  year  \
# 0                   United DJs Of America - Volume 14     56598  2000
# 1                           Blazing The Crop - Rewind   2010288  2002
# 2   Monsieur Dimitri's De-Luxe House Of Funk - Rewind    559306  2001
# 3                                              Rewind    340431  2001
# 4                   United DJs Of America - Volume 15      2511  2000
# 5                       United DJs Of America Vol. 20    797916  2003
# 6                   United DJs Of America - Volume 18     48497  2002
# 7                   United DJs Of America - Volume 16     60588  2000
# 8                 One Sound System One Music - Rewind    579264  2001
# 9                   United DJs Of America - Volume 18     48497  2002
# 10                                       Back To Mine    521631  2002
# 11                               Next School Volume 2    432833  2002
# 12                                    Drum'n'Bass Mix    109318  2001
# 13                  United DJs Of America - Volume 19   2829291  2001
# 14                          The Takeover Bid - Rewind    637918  2001
# 15                                 Resonance - Rewind    558113  2001
# 16                  United DJs Of America - Volume 17    221053  2001
# 17                                       Back To Mine    565185  2003
# 18                                         In America   4202627  2002
# 19                    Electro Funk Breakdown - Rewind    569231  2001
# 20                               Next School Volume 1   4645352  2002
# 21                                  Drum 'N' Bass Mix   1128246  2002
# 22  United DJs Of America - Volume 13: Electro Fun...  11296550  1999
# 23  United DJs Of America - Volume 13: Electro Fun...     70913  1999
# 24  United DJ's Of America Volume 10: Resonance ‎-...     67015  1998
# 25       United DJs Of America Volume 11: My First CD    141176  1999
# 26   Mixer In Association With United DJs Of Ameri...   2306628  1999
# 27  Mixer In Association With United DJs Of Americ...   1430785  1999
# 28                  United DJs Of America - Volume 14   1445008  2000
# 29                  United DJs Of America - Volume 14   4358707  2000
# 30                        The Takeover Bid: Round One    249123  1998
# 31                        The Takeover Bid: Round Two    646382  1998
# 32                        The Takeover Bid: Round One   6083940  1998
# 33                        The Takeover Bid: Round Two   6083948  1998
# 34                                 A Jedi's Night Out        49  1999
# 35                                 Anarchy In The USA   4110434  1999
# 36                                   Blazing The Crop    210153  2000
#
#                                        artist
# 0                               Soul Slinger*
# 1                          Rae And Christian*
# 2                          Dimitri From Paris
# 3                                 Mark Farina
# 4                              David Alvarado
# 5                               Marques Wyatt
# 6                              Tony Humphries
# 7                                    DJ Craze
# 8   Soul Slinger* Featuring Supa MC TC Izlam*
# 9                              Tony Humphries
# 10                                    Orbital
# 11                                  Plus One*
# 12                                   J.Majik*
# 13                                John Kelley
# 14                                  Aphrodite
# 15                                     Taylor
# 16                             Scott Hardkiss
# 17                                    The Orb
# 18                                       Slam
# 19                           Afrika Bambaataa
# 20                                     Yousef
# 21                                 Micky Finn
# 22                           Afrika Bambaataa
# 23                           Afrika Bambaataa
# 24                                     Taylor
# 25                               Cevin Fisher
# 26                                       Murk
# 27                                       Murk
# 28                              Soul Slinger*
# 29                              Soul Slinger*
# 30                                  Aphrodite
# 31                                 Micky Finn
# 32                                  Aphrodite
# 33                                 Micky Finn
# 34                              Tom Middleton
# 35                            Deejay Punk-Roc
# 36                            Rae & Christian

# %%
releases_count = len(df_label_info['releases'])
print("Number of releases for page 1:", releases_count)
# Out:
# Number of releases for page 1: 37

# %%
release_years = [release['year'] for release in df_label_info['releases']]
max_year = max(release_years)
min_year = min(release_years)

print("Maximum release year:", max_year)
print("Minimum release year:", min_year)
# Out:
# Maximum release year: 2003
# Minimum release year: 1998

# %%
df_label_info_normalized.columns
# Out:
# Index(['status', 'format', 'catno', 'thumb', 'resource_url', 'title', 'id',
#        'year', 'artist', 'num_of_releases', 'min_release_year',
#        'max_release_year'],
#       dtype='object')

# %%
# filtered_df = df_label_info[df_label_info['releases'].apply(lambda x: x['year'] == 2003 or x['year'] == 1998)]

# filtered_df

# %%
# filtered_df = df_label_info[df_label_info['releases'].apply(lambda x: x['year'] == 2003 or x['year'] == 1998)]
# for index, row in filtered_df.iterrows():
#     releases = row['releases']
#     year = releases['year']
#     print(f"Releases: {releases}, Year: {year}")
# Out:
# Releases: {'status': 'Accepted', 'format': 'CD, Mixed', 'catno': '7930185516-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/797916', 'title': 'United DJs Of America Vol. 20', 'id': 797916, 'year': 2003, 'artist': 'Marques Wyatt'}, Year: 2003
# Releases: {'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': '7930185523-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/565185', 'title': 'Back To Mine', 'id': 565185, 'year': 2003, 'artist': 'The Orb'}, Year: 2003
# Releases: {'status': 'Accepted', 'format': 'CD, Mixed', 'catno': 'DM40009-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/67015', 'title': "United DJ's Of America Volume 10: Resonance \u200e- Los Angeles", 'id': 67015, 'year': 1998, 'artist': 'Taylor'}, Year: 1998
# Releases: {'status': 'Accepted', 'format': 'CD, Comp, Mixed', 'catno': 'MIX 60008-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/249123', 'title': 'The Takeover Bid: Round One', 'id': 249123, 'year': 1998, 'artist': 'Aphrodite'}, Year: 1998
# Releases: {'status': 'Accepted', 'format': 'CD, Mixed', 'catno': 'MIX 60009-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/646382', 'title': 'The Takeover Bid: Round Two', 'id': 646382, 'year': 1998, 'artist': 'Micky Finn'}, Year: 1998
# Releases: {'status': 'Accepted', 'format': 'CD, Comp, Mixed, Promo', 'catno': 'MIX60008-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/6083940', 'title': 'The Takeover Bid: Round One', 'id': 6083940, 'year': 1998, 'artist': 'Aphrodite'}, Year: 1998
# Releases: {'status': 'Accepted', 'format': 'CD, Comp, Mixed, Promo', 'catno': 'MIX60009-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/6083948', 'title': 'The Takeover Bid: Round Two', 'id': 6083948, 'year': 1998, 'artist': 'Micky Finn'}, Year: 1998

# %% [markdown]
# Consumer Key	BlLxXNiHJoVLBApblBoO
#
# Consumer Secret	grxJeFlhvKDYugDExZeNfEyegmudzdLY
#
# Request Token URL	https://api.discogs.com/oauth/request_token
#
# Authorize URL	https://www.discogs.com/oauth/authorize
#
# Access Token URL	https://api.discogs.com/oauth/access_token

# %%
pip install discogs_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting discogs_client
#   Downloading discogs_client-2.3.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from discogs_client) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from discogs_client) (1.16.0)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.10/dist-packages (from discogs_client) (3.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->discogs_client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->discogs_client) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->discogs_client) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->discogs_client) (3.4)
# Installing collected packages: discogs_client
# Successfully installed discogs_client-2.3.0

# %%
import discogs_client

# Replace with your own consumer key and secret
consumer_key = 'BlLxXNiHJoVLBApblBoO'
consumer_secret = 'grxJeFlhvKDYugDExZeNfEyegmudzdLY'

# Create a Discogs client object
discogs = discogs_client.Client('YourApp/1.0', consumer_key=consumer_key, consumer_secret=consumer_secret)

# Get the OAuth request token
request_token, request_secret, authorize_url = discogs.get_authorize_url()

# Print a message with instructions for manual authorization
print("Please authorize the application by visiting the following URL:")
print(authorize_url)
# Out:
# Please authorize the application by visiting the following URL:
# https://www.discogs.com/oauth/authorize?oauth_token=QMvdDMMwGyHMKdOfoIdZKUbZUoZxekzwUcuPxpgS

# %%
# After authorizing the application, Discogs will redirect you to a callback URL.
# Extract the `oauth_verifier` parameter from the URL.
# You can manually copy it or programmatically retrieve it using a library like Flask.

# Once you have the `oauth_verifier`, you can authenticate the client.
oauth_verifier = 'bWxzRdhoSu'  # Replace with the actual oauth_verifier value
access_token, access_secret = discogs.get_access_token(oauth_verifier)

# Set the access token and secret for further API requests
discogs.set_token(access_token, access_secret)

# Now you can make authenticated requests to the Discogs API
# For example, to get your user identity:
user = discogs.identity()
print("Authenticated user:", user.username)
# Out:
# Please visit the following URL to authorize the application:
# ('rbbBalYPcATcvKurFHDLmJOKZyPkGOjlXaRAdnxx', 'OXSUTyrQHmsBOgdJSxXpTyXafDsteWhROWZdRRSC', 'https://www.discogs.com/oauth/authorize?oauth_token=rbbBalYPcATcvKurFHDLmJOKZyPkGOjlXaRAdnxx')
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-34-abc03629e25c> in <cell line: 23>()
#      21 # Once you have the `oauth_verifier`, you can authenticate the client.
#      22 oauth_verifier = 'wnaBVBSNoR'  # Replace with the actual oauth_verifier value
# ---> 23 access_token, access_secret = discogs.get_access_token(oauth_verifier)
#      24
#      25 # Set the access token and secret for further API requests
#
# /usr/local/lib/python3.10/dist-packages/discogs_client/client.py in get_access_token(self, verifier)
#      84         content, status_code = self._fetcher.fetch(self, 'POST', self._access_token_url, headers=params)
#      85         if status_code != 200:
# ---> 86             raise HTTPError('Invalid response from access token URL.', status_code)
#      87
#      88         token, secret = self._fetcher.store_token_from_qs(content)
#
# HTTPError: 400: Invalid response from access token URL.

# %%
import requests

response = requests.get('https://api.discogs.com/releases/')
user_agent = response.request.headers['User-Agent']

print(user_agent)
# Out:
# python-requests/2.27.1

# %%
def add_additional_columns(df):
    print(f"{time.strftime('%H:%M:%S')}|Begin API calls for additional label info ({len(df)} labels)")
    failed_labels = []
    for index, row in df.iterrows():
        label_id = row['id']
        label_info = get_label_info(label_id)
        print(label_info)
        if label_info is not None:
            release_years = [release['year'] for release in label_info['releases']]
            if release_years:
                max_year = max(release_years)
                min_year = min(release_years)
            else:
                max_year = None
                min_year = None

            # Add additional columns to the DataFrame
            df.at[index, 'num_of_releases'] = len(label_info['releases'])
            df.at[index, 'min_release_year'] = min_year
            df.at[index, 'max_release_year'] = max_year
        else:
            failed_labels.append(label_id)

        # Implement rate limiting to avoid hitting the API rate limit
        time.sleep(2)  # Adjust the sleep duration as needed

    if failed_labels:
        print(f"{time.strftime('%H:%M:%S')}|Failed API calls for labels: {', '.join(str(l) for l in failed_labels)}")

    df['num_of_releases'] = df['num_of_releases'].fillna(0).astype(int)
    df['min_release_year'] = df['min_release_year'].fillna(0).astype(int)
    df['max_release_year'] = df['max_release_year'].fillna(0).astype(int)
    df = df[['id','name','contactinfo','profile','parentLabel','num_of_releases','min_release_year','max_release_year']]
    return df
# df_label_inf = pd.DataFrame(df_label_info)  # Create or load your DataFrame here
add_col = add_additional_columns(df_label_info_normalized)
print(add_col)
# Out:
# 15:41:05|Begin API calls for additional label info (37 labels)
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 1, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': '7", S/Sided, Cre', 'catno': 'UC 0000', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/614361', 'title': 'Untitled', 'id': 614361, 'year': 1994, 'artist': 'Kyau'}]}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 4, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': '7", EP', 'catno': 'EP 105', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/22688588', 'title': 'Without Him', 'id': 22688588, 'year': 1965, 'artist': 'Silver Keys Quartet'}, {'status': 'Accepted', 'format': '7"', 'catno': 'none', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/16866594', 'title': "Because Of Him / I'll Really Be Free", 'id': 16866594, 'year': 1965, 'artist': 'The Spiritual-Aires'}, {'status': 'Accepted', 'format': '7", EP', 'catno': 'none', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/16869549', 'title': 'Silver And Gold', 'id': 16869549, 'year': 1964, 'artist': 'Galilean Quartet*'}, {'status': 'Accepted', 'format': '7"', 'catno': 'none', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/16869573', 'title': 'Loneliest Night / The Leaves Are Falling', 'id': 16869573, 'year': 1964, 'artist': 'Marcella Dotson'}]}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 2, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': 'File, MP3, 320', 'catno': 'GNR003', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/4682061', 'title': 'Deep Inspired ', 'id': 4682061, 'year': 2013, 'artist': 'Xio (2)'}, {'status': 'Accepted', 'format': '5xFile, MP3, 320', 'catno': 'GNR015', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/7241966', 'title': 'Freitag Unterhaltung', 'id': 7241966, 'year': 2014, 'artist': 'Paul Begge & Nik Carter (3)'}]}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 2, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': 'CD, Album', 'catno': 'PCD-5421', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3350946', 'title': 'Do The Rump!', 'id': 3350946, 'year': 1998, 'artist': 'Junior Kimbrough And The Soul Blues Boys'}, {'status': 'Accepted', 'format': 'CD, Album, RE', 'catno': 'PCD-5474', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/13002335', 'title': 'She-Wolf', 'id': 13002335, 'year': 1998, 'artist': 'Jessie Mae Hemphill'}]}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 7, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': '12", TP', 'catno': 'NIR-001', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/1164223', 'title': 'Come With Me', 'id': 1164223, 'year': 2000, 'artist': 'Mazi* Feat. Rheji'}, {'status': 'Accepted', 'format': '12"', 'catno': 'NIR-002', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/11392', 'title': 'Never Gonna Let U Go', 'id': 11392, 'year': 0, 'artist': 'Stacy Kidd'}, {'status': 'Accepted', 'format': '12"', 'catno': 'NIR-401', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/23715', 'title': 'Come With Me', 'id': 23715, 'year': 2000, 'artist': 'Mazi* Featuring Rheji'}, {'status': 'Accepted', 'format': '12"', 'catno': 'NIR-402', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/12043', 'title': 'Finger Fuck', 'id': 12043, 'year': 2001, 'artist': 'Paul Johnson'}, {'status': 'Accepted', 'format': '12", TP, W/Lbl', 'catno': 'NIR-402', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/1982782', 'title': 'Finger F--k', 'id': 1982782, 'year': 2001, 'artist': 'Paul Johnson Featuring Jessica (6)'}, {'status': 'Accepted', 'format': '12", Promo, W/Lbl', 'catno': 'NIR-403', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/1157083', 'title': 'Give Me All Your Love', 'id': 1157083, 'year': 2001, 'artist': 'Paul Johnson'}, {'status': 'Accepted', 'format': '12"', 'catno': 'NIR-403', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/12044', 'title': 'Give Me All Your Love', 'id': 12044, 'year': 2001, 'artist': 'Paul Johnson'}]}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 0, 'urls': {}}, 'releases': []}
# 15:41:19 | Failed API call for label 48497
# None
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 0, 'urls': {}}, 'releases': []}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 1, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': 'CDr', 'catno': 'none', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/4826542', 'title': 'We Fast Armageddon And Rebellion Bastard 2way Split', 'id': 4826542, 'year': 2012, 'artist': 'Triturador / Kekuatan Super'}]}
# 15:41:27 | Failed API call for label 48497
# None
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 8, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': '2xCD, Album, RE', 'catno': 'ALPH DCD 022', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/6622964', 'title': 'Sing To God', 'id': 6622964, 'year': 0, 'artist': 'Cardiacs'}, {'status': 'Accepted', 'format': 'CD, Album', 'catno': 'ALPH CD030, ALPH CD 030', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/1388553', 'title': 'The Special Garage Concerts London Autumn 2003 Vol I', 'id': 1388553, 'year': 2005, 'artist': 'Cardiacs'}, {'status': 'Accepted', 'format': '2xLP, Album, RE, RP', 'catno': 'ALPH DLP 022', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/17161870', 'title': 'Sing To God', 'id': 17161870, 'year': 2014, 'artist': 'Cardiacs'}, {'status': 'Accepted', 'format': '2xCD, Album, Ltd', 'catno': 'ALPH DCD 022', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/1388690', 'title': 'Sing To God', 'id': 1388690, 'year': 1996, 'artist': 'Cardiacs'}, {'status': 'Accepted', 'format': '2xCD, Album, RE, RP', 'catno': 'ALPH DCD 022', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/26156174', 'title': 'Sing To God', 'id': 26156174, 'year': 0, 'artist': 'Cardiacs'}, {'status': 'Accepted', 'format': '2xCD, Comp', 'catno': 'ALPH DCD031', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/6058474', 'title': 'The Special Garage Concerts', 'id': 6058474, 'year': 2014, 'artist': 'Cardiacs'}, {'status': 'Accepted', 'format': '2xLP, Album, Ltd, Num, RE', 'catno': 'ALPH DLP 022', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/5915357', 'title': 'Sing To God', 'id': 5915357, 'year': 2014, 'artist': 'Cardiacs'}, {'status': 'Accepted', 'format': 'CD, Album', 'catno': 'ALPH CD031, ALPH CD 031', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/1388550', 'title': 'The Special Garage Concerts London Autumn 2003 Vol II', 'id': 1388550, 'year': 2005, 'artist': 'Cardiacs'}]}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 11, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': '4xFile, MP3, EP, 320', 'catno': 'GLR001', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3816848', 'title': 'Boom Boom Ep', 'id': 3816848, 'year': 2011, 'artist': 'Pepe Arcade'}, {'status': 'Accepted', 'format': '3xFile, WAV, EP', 'catno': 'GLR002', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3816858', 'title': 'Neutrino EP', 'id': 3816858, 'year': 2011, 'artist': 'Analog People'}, {'status': 'Accepted', 'format': '2xFile, WAV', 'catno': 'GLR004', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3816911', 'title': 'Loki Vs Prometeo', 'id': 3816911, 'year': 2011, 'artist': 'Analog People'}, {'status': 'Accepted', 'format': '2xFile, WAV', 'catno': 'GLR005', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3816921', 'title': 'Terracota', 'id': 3816921, 'year': 2011, 'artist': 'Analog People'}, {'status': 'Accepted', 'format': '6xFile, WAV', 'catno': 'GLR009', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3816952', 'title': 'G2', 'id': 3816952, 'year': 2011, 'artist': 'Analog People'}, {'status': 'Accepted', 'format': '3xFile, MP3, 320', 'catno': 'GLR012', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3819825', 'title': 'Spacekraft', 'id': 3819825, 'year': 2011, 'artist': 'Analog People'}, {'status': 'Accepted', 'format': '4xFile, WAV', 'catno': 'GLR014', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3594908', 'title': 'Wet', 'id': 3594908, 'year': 2012, 'artist': 'Audio Louis'}, {'status': 'Accepted', 'format': '4xFile, MP3, 320', 'catno': 'GLR014', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3819871', 'title': 'Wet', 'id': 3819871, 'year': 2012, 'artist': 'Audio Louis'}, {'status': 'Accepted', 'format': '4xFile, MP3, 320', 'catno': 'GLR016', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3829014', 'title': 'Everdub', 'id': 3829014, 'year': 2012, 'artist': 'Ismael Serrano'}, {'status': 'Accepted', 'format': '4xFile, MP3, 320', 'catno': 'GLR017', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3829025', 'title': 'My World', 'id': 3829025, 'year': 2012, 'artist': 'Analog People'}, {'status': 'Accepted', 'format': '5xFile, MP3, 320', 'catno': 'GLR019', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3829068', 'title': 'Cave 5', 'id': 3829068, 'year': 2012, 'artist': 'Analog People'}]}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 0, 'urls': {}}, 'releases': []}
# 15:41:36 | Failed API call for label 2829291
# None
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 0, 'urls': {}}, 'releases': []}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 0, 'urls': {}}, 'releases': []}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 0, 'urls': {}}, 'releases': []}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 6, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': 'CD, MiniAlbum', 'catno': 'CDSWm10', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/9154620', 'title': 'Hide', 'id': 9154620, 'year': 1996, 'artist': 'Malka Spigel'}, {'status': 'Accepted', 'format': '12"', 'catno': 'Vwm 11', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/96267', 'title': 'Prepare For The Others To Follow (Remixes)', 'id': 96267, 'year': 1996, 'artist': "Pablo's Eye"}, {'status': 'Accepted', 'format': '2xCD, Comp', 'catno': 'DWm20', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/96268', 'title': 'Water Communication', 'id': 96268, 'year': 1997, 'artist': 'Various'}, {'status': 'Accepted', 'format': 'CD, Album', 'catno': 'WM15', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/96744', 'title': 'In Glorious Black And Blue', 'id': 96744, 'year': 1997, 'artist': 'Ronnie & Clyde*'}, {'status': 'Accepted', 'format': 'CD, Album', 'catno': 'Vwm16, Vwm 16', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/96746', 'title': 'Cryptic Audio', 'id': 96746, 'year': 1997, 'artist': 'Dol-lop'}, {'status': 'Accepted', 'format': 'CD, Comp', 'catno': 'Spark 39', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/571742', 'title': 'Zwei Welten', 'id': 571742, 'year': 1994, 'artist': 'Various'}]}
# 15:41:46 | Failed API call for label 4202627
# None
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 3, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': 'CD, Album', 'catno': 'ADD025', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/4753203', 'title': "This Gent's A Scoundrel", 'id': 4753203, 'year': 2005, 'artist': 'Rcade Inferno'}, {'status': 'Accepted', 'format': 'CD, Album', 'catno': 'ADD025', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/4753203', 'title': "This Gent's A Scoundrel", 'id': 4753203, 'year': 2005, 'artist': 'Rcade Inferno'}, {'status': 'Accepted', 'format': 'CD, Album', 'catno': 'ADD025', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/4753203', 'title': "This Gent's A Scoundrel", 'id': 4753203, 'year': 2005, 'artist': 'Rcade Inferno'}]}
# 15:41:51 | Failed API call for label 4645352
# None
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 1, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': 'CD, Album', 'catno': 'MCM 2001-17', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/9475768', 'title': 'Ein Licht Scheint In Der Dunkelheit (Weihnachtslieder Für Kleine Und Grosse Leute)', 'id': 9475768, 'year': 2001, 'artist': 'Jonathan Böttcher'}]}
# 15:41:55 | Failed API call for label 11296550
# None
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 7, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': 'CD, EP', 'catno': 'MA0006', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/10886608', 'title': 'The Time And Space Machine Dub Sessions', 'id': 10886608, 'year': 2013, 'artist': 'Jagwar Ma'}, {'status': 'Accepted', 'format': '12", Ltd, Num', 'catno': 'SFS 78', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/19969072', 'title': 'R.P.M.', 'id': 19969072, 'year': 1978, 'artist': 'McLeish, Petrie Robinson & Friends'}, {'status': 'Accepted', 'format': 'CD, Album', 'catno': 'SR-127-02', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/2862563', 'title': 'The Images We Get', 'id': 2862563, 'year': 2011, 'artist': 'Sugarplum Fairies'}, {'status': 'Accepted', 'format': 'CD, Album', 'catno': 'SR1242', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/2513991', 'title': 'Introspective Raincoat Student Music', 'id': 2513991, 'year': 2003, 'artist': 'Sugarplum Fairies'}, {'status': 'Accepted', 'format': 'CD, Album, Dig', 'catno': 'SR126-2', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/2513995', 'title': 'Chinese Leftovers', 'id': 2513995, 'year': 2009, 'artist': 'Sugarplum Fairies'}, {'status': 'Accepted', 'format': '7", Single', 'catno': 'STF7', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3091676', 'title': 'Turbulence #5 / Sister Stiletto', 'id': 3091676, 'year': 1996, 'artist': 'American TV Cops'}, {'status': 'Accepted', 'format': 'CD, Single', 'catno': 'STFD7', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/3440573', 'title': 'Turbulence #5', 'id': 3440573, 'year': 1996, 'artist': 'American TV Cops'}]}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 0, 'urls': {}}, 'releases': []}
# {'pagination': {'page': 1, 'pages': 1, 'per_page': 50, 'items': 2, 'urls': {}}, 'releases': [{'status': 'Accepted', 'format': 'CDr, Album', 'catno': 'none', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/12996260', 'title': 'Fog Of War', 'id': 12996260, 'year': 2002, 'artist': 'Rationale'}, {'status': 'Accepted', 'format': '12"', 'catno': 'RVN-001', 'thumb': '', 'resource_url': 'https://api.discogs.com/releases/1654821', 'title': 'F.U. / Fool', 'id': 1654821, 'year': 0, 'artist': 'Rationale'}]}
# 15:42:04 | Failed API call for label 2306628
# None
# 15:42:06 | Failed API call for label 1430785
# None
# 15:42:08 | Failed API call for label 1445008
# None
# 15:42:10 | Failed API call for label 4358707
# None
# 15:42:12 | Failed API call for label 249123
# None
# 15:42:15 | Failed API call for label 646382
# None
# 15:42:17 | Failed API call for label 6083940
# None
# 15:42:19 | Failed API call for label 6083948
# None
# 15:42:21 | Failed API call for label 49
# None
# 15:42:23 | Failed API call for label 4110434
# None
# 15:42:25 | Failed API call for label 210153
# None
# 15:42:27|Failed API calls for labels: 48497, 48497, 2829291, 4202627, 4645352, 11296550, 2306628, 1430785, 1445008, 4358707, 249123, 646382, 6083940, 6083948, 49, 4110434, 210153
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 36
#      34     return df
#      35 # df_label_inf = pd.DataFrame(df_label_info)  # Create or load your DataFrame here
# ---> 36 add_col = add_additional_columns(df_label_info_normalized)
#      37 print(add_col)
#
# Cell In[23], line 33, in add_additional_columns(df)
#      31 df['min_release_year'] = df['min_release_year'].fillna(0).astype(int)
#      32 df['max_release_year'] = df['max_release_year'].fillna(0).astype(int)
# ---> 33 df = df[['id','name','contactinfo','profile','parentLabel','num_of_releases','min_release_year','max_release_year']]
#      34 return df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['name', 'contactinfo', 'profile', 'parentLabel'] not in index"

# %%
df_new = pd.concat([df1[['id', 'name', 'contactinfo', 'profile']], add_col[['num_of_releases', 'min_release_year', 'max_release_year']].copy()], axis=1)

# %%
df_new
# Out:
#           id                name  \
# 725    774.0   Hed Kandi Records
# 2878  3141.0             Concept
# 2935  3203.0  Tinnitus Tonträger
# 3020  3295.0  Taaach! Recordings
# 3505  3824.0                Fuse
# ...      ...                 ...
# 32       NaN                 NaN
# 33       NaN                 NaN
# 34       NaN                 NaN
# 35       NaN                 NaN
# 36       NaN                 NaN
#
#                                             contactinfo  \
# 725   MSHK Limited\r\n103 Gaunt Street\r\nLondon, SE...
# 2878  Concept Records\r\n24A Barry Street\r\nBradfor...
# 2935  Tinnitus Tonträger\r\nMarc Göttling\r\nWiesent...
# 3020  Taaach!\r\nEdition Chrome\r\nPostfach 10 50 54...
# 3505  Fuse\r\nbkb Dance Department gmbh\r\nAuhofstra...
# ...                                                 ...
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
#
#                                                 profile  num_of_releases  \
# 725   Record company of the UK-based house label [l6...              NaN
# 2878  Trance label from the UK. The label becomes [l...              NaN
# 2935          Style: hard kicking minimal techno traxx.              NaN
# 3020  German Trance Label\r\nDistributed by InterGro...              NaN
# 3505  German Trance label\r\nDistributed by Music Ma...              NaN
# ...                                                 ...              ...
# 32                                                  NaN              0.0
# 33                                                  NaN              0.0
# 34                                                  NaN             41.0
# 35                                                  NaN              0.0
# 36                                                  NaN              1.0
#
#       min_release_year  max_release_year
# 725                NaN               NaN
# 2878               NaN               NaN
# 2935               NaN               NaN
# 3020               NaN               NaN
# 3505               NaN               NaN
# ...                ...               ...
# 32                 0.0               0.0
# 33                 0.0               0.0
# 34              1997.0            2006.0
# 35                 0.0               0.0
# 36              2007.0            2007.0
#
# [464 rows x 7 columns]

# %%
add_col.columns
# Out:
# Index(['status', 'format', 'catno', 'thumb', 'resource_url', 'title', 'id',
#        'year', 'artist', 'num_of_releases', 'min_release_year',
#        'max_release_year'],
#       dtype='object')

# %%
add_col.dtypes
# Out:
# status              object
# format              object
# catno               object
# thumb               object
# resource_url        object
# title               object
# id                   int64
# year                 int64
# artist              object
# num_of_releases      int32
# min_release_year     int32
# max_release_year     int32
# dtype: object

# %%
# add_col['num_of_releases'] = add_col['num_of_releases'].fillna(0).astype(int)
# add_col['min_release_year'] = add_col['min_release_year'].fillna(0).astype(int)
# add_col['max_release_year'] = add_col['max_release_year'].fillna(0).astype(int)

# %%
# Function to load the transformed DataFrame into PostgreSQL
def load(df):
    print(f"{time.strftime('%H:%M:%S')}|Successful load of labels table into PostgreSQL")
    # Establish a connection to the PostgreSQL database
    conn = psycopg2.connect(
        host='your_host',
        port='your_port',
        dbname='your_database',
        user='your_user',
        password='your_password'
    )

    # Create the labels table if it doesn't exist
    create_table_query = """
    CREATE TABLE IF NOT EXISTS labels (
        id SERIAL PRIMARY KEY,
        name VARCHAR(255),
        contactinfo TEXT,
        profile TEXT,
        parentLabel VARCHAR(255),
        num_of_releases INTEGER,
        min_release_year INTEGER,
        max_release_year INTEGER
    )
    """
    with conn.cursor() as cursor:
        cursor.execute(create_table_query)
        conn.commit()

    # Load the transformed DataFrame into the labels table
    with conn.cursor() as cursor:
        for _, row in df.iterrows():
            insert_query = """
            INSERT INTO labels (name, contactinfo, profile, parentLabel, num_of_releases, min_release_year, max_release_year)
            VALUES (%s, %s, %s, %s, %s, %s, %s)
            """
            values = (
                row['name'],
                row['contactinfo'],
                row['profile'],
                row['parentLabel'],
                row['num_of_releases'],
                row['min_release_year'],
                row['max_release_year']
            )
            cursor.execute(insert_query, values)
        conn.commit()

    conn.close()

# %%
# Main function to orchestrate the ETL process
def main():
    df = extract()
    # df = transform(df)
    df = add_additional_columns(df)
    load(df)

if __name__ == '__main__':
    main()
# Out:
# 14:51:18|Begin API calls for additional label info (1946246 labels)
# {'id': 1, 'name': 'Planet E', 'resource_url': 'https://api.discogs.com/labels/1', 'uri': 'https://www.discogs.com/label/1-Planet-E', 'releases_url': 'https://api.discogs.com/labels/1/releases', 'images': [{'type': 'primary', 'uri': '', 'resource_url': '', 'uri150': '', 'width': 132, 'height': 24}, {'type': 'secondary', 'uri': '', 'resource_url': '', 'uri150': '', 'width': 587, 'height': 126}, {'type': 'secondary', 'uri': '', 'resource_url': '', 'uri150': '', 'width': 600, 'height': 196}, {'type': 'secondary', 'uri': '', 'resource_url': '', 'uri150': '', 'width': 275, 'height': 121}, {'type': 'secondary', 'uri': '', 'resource_url': '', 'uri150': '', 'width': 382, 'height': 720}, {'type': 'secondary', 'uri': '', 'resource_url': '', 'uri150': '', 'width': 500, 'height': 398}, {'type': 'secondary', 'uri': '', 'resource_url': '', 'uri150': '', 'width': 600, 'height': 189}], 'contact_info': 'Planet E Communications\r\nP.O. Box 27218\r\nDetroit, Michigan, MI 48227\r\nUSA\r\n\r\nPhone: +1 313 874 8729\r\nFax: +1 313 874 8732\r\nEmail: info@Planet-e.net', 'profile': "[a=Carl Craig]'s classic techno label founded in 1991.\r\n\r\nOn at least 1 release, Planet E is listed as publisher.", 'data_quality': 'Needs Vote', 'urls': ['http://planet-e.net', 'http://planetecommunications.bandcamp.com', 'http://www.facebook.com/planetedetroit', 'http://www.flickr.com/photos/planetedetroit', 'http://www.instagram.com/carlcraignet', 'http://myspace.com/planetecom', 'http://myspace.com/planetedetroit', 'http://soundcloud.com/planetedetroit', 'http://twitter.com/planetedetroit', 'http://vimeo.com/user1265384', 'http://en.wikipedia.org/wiki/Planet_E_Communications', 'http://www.youtube.com/user/planetedetroit'], 'sublabels': [{'id': 86537, 'name': 'Antidote (4)', 'resource_url': 'https://api.discogs.com/labels/86537'}, {'id': 41841, 'name': 'Community Projects', 'resource_url': 'https://api.discogs.com/labels/41841'}, {'id': 153760, 'name': 'Guilty Pleasures', 'resource_url': 'https://api.discogs.com/labels/153760'}, {'id': 31405, 'name': 'I Ner Zon Sounds', 'resource_url': 'https://api.discogs.com/labels/31405'}, {'id': 277579, 'name': 'Planet E Communications', 'resource_url': 'https://api.discogs.com/labels/277579'}, {'id': 294738, 'name': 'Planet E Communications, Inc.', 'resource_url': 'https://api.discogs.com/labels/294738'}, {'id': 1560615, 'name': 'Planet E Productions', 'resource_url': 'https://api.discogs.com/labels/1560615'}, {'id': 488315, 'name': 'TWPENTY', 'resource_url': 'https://api.discogs.com/labels/488315'}]}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-4bf0e13112ff> in <cell line: 8>()
#       7
#       8 if __name__ == '__main__':
# ----> 9     main()
#
# <ipython-input-14-4bf0e13112ff> in main()
#       3     df = extract()
#       4     # df = transform(df)
# ----> 5     df = add_additional_columns(df)
#       6     load(df)
#       7
#
# <ipython-input-13-249ece7043f1> in add_additional_columns(df)
#       9         if label_info is not None:
#      10             # Add additional columns to the DataFrame
# ---> 11             df.at[index, 'num_of_releases'] = label_info['num_of_releases']
#      12             df.at[index, 'min_release_year'] = label_info['min_release_year']
#      13             df.at[index, 'max_release_year'] = label_info['max_release_year']
#
# KeyError: 'num_of_releases'
